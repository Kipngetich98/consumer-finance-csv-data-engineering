# %%
import pandas as pd

# Read the data and the first 100 rows

# df = pd.read_csv('/home/vincent/Downloads/SCFP2019.csv', nrows=100)
df = pd.read_csv("/app/SCFP2019.csv", nrows=100)
# nrows -> first n amount of rows you want to read
df.head()
# Out:
#    YY1  Y1          WGT  HHSEX  AGE  AGECL  EDUC  EDCL  MARRIED  KIDS  ...  \
# 0    1  11  6119.779308      2   75      6    12     4        2     0  ...
# 1    1  12  4712.374912      2   75      6    12     4        2     0  ...
# 2    1  13  5145.224455      2   75      6    12     4        2     0  ...
# 3    1  14  5297.663412      2   75      6    12     4        2     0  ...
# 4    1  15  4761.812371      2   75      6    12     4        2     0  ...
#
#    NWCAT  INCCAT  ASSETCAT  NINCCAT  NINC2CAT  NWPCTLECAT  INCPCTLECAT  \
# 0      5       3         6        3         2          10            6
# 1      5       3         6        3         1          10            5
# 2      5       3         6        3         1          10            5
# 3      5       2         6        2         1          10            4
# 4      5       3         6        3         1          10            5
#
#    NINCPCTLECAT  INCQRTCAT  NINCQRTCAT
# 0             6          3           3
# ...

# %% [markdown]
# put the data to postgres

# %%
#generate a schema of the dataset, which is an instruction to create a table that specifies what kind of columns you want to have there and their types
pd.io.sql.get_schema(df, name="consumer_data")

#The get_schema function converts your Pandas "Dataframe" to a DDL which is used for specifying schemas. This function outputs a CREATE TABLE sql statement with table name being "consumer_data"
print(pd.io.sql.get_schema(df, name="consumer_data"))
# Out:
# CREATE TABLE "consumer_data" (
# "YY1" INTEGER,
#   "Y1" INTEGER,
#   "WGT" REAL,
#   "HHSEX" INTEGER,
#   "AGE" INTEGER,
#   "AGECL" INTEGER,
#   "EDUC" INTEGER,
#   "EDCL" INTEGER,
#   "MARRIED" INTEGER,
#   "KIDS" INTEGER,
#   "LF" INTEGER,
#   "LIFECL" INTEGER,
#   "FAMSTRUCT" INTEGER,
#   "RACECL" INTEGER,
#   "RACECL4" INTEGER,
#   "RACE" INTEGER,
#   "OCCAT1" INTEGER,
#   "OCCAT2" INTEGER,
#   "INDCAT" INTEGER,
#   "FOODHOME" INTEGER,
#   "FOODAWAY" INTEGER,
#   "FOODDELV" INTEGER,
#   "RENT" INTEGER,
#   "INCOME" REAL,
#   "WAGEINC" REAL,
#   "BUSSEFARMINC" REAL,
#   "INTDIVINC" REAL,
#   "KGINC" REAL,
#   "SSRETINC" REAL,
#   "TRANSFOTHINC" REAL,
#   "PENACCTWD" REAL,
#   "NORMINC" REAL,
#   "WSAVED" INTEGER,
#   "SAVED" INTEGER,
#   "SAVRES1" INTEGER,
#   "SAVRES2" INTEGER,
#   "SAVRES3" INTEGER,
#   "SAVRES4" INTEGER,
#   "SAVRES5" INTEGER,
#   "SAVRES6" INTEGER,
#   "SAVRES7" INTEGER,
#   "SAVRES8" INTEGER,
#   "SAVRES9" INTEGER,
#   "SPENDMOR" INTEGER,
# ...

# %% [markdown]
# # Putting the schema into postgresql

# %%
from sqlalchemy import create_engine

# specify the database you want to use based on the docker run command we had
# postgresql://username:password@localhost:port/dbname
engine = create_engine('postgresql://postgres:1234@localhost:5435/consumer_data')

# create the connection to the database engine to see if everything is working properly
engine.connect()

# pass the engine variable to get_schema function
# Pandas will execute the schema SQL statement using the engine connection we have defined
pd.io.sql.get_schema(df, name="consumer_data", con=engine)

# %% [markdown]
# Since the data is big, use chunks and iterator to process

# %%
df_iter = pd.read_csv('/home/vincent/Downloads/SCFP2019.csv', iterator=True, chunksize=100000)


df = next(df_iter)
# len(df) -> 100000

# %%
# get only the name of the columns and no data
df.head(n=0)

# %% [markdown]
# # Transform the DataFrame to SQL

# %%
df.to_sql(name="yellow_taxi_data", con=engine, if_exists="replace")

# %% [markdown]
#  # Insert Data to database table

# %%
df.to_sql(name="yellow_taxi_data", con=engine, if_exists="append")
